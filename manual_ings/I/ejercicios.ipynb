# %% [markdown]
# # Repaso

# %%
from jupyterquiz import display_quiz

color_dict = {
    '--jq-multiple-choice-bg': '#4ea2d9',     # Azul claro para preguntas tipo opción múltiple
    '--jq-mc-button-bg': '#fafafa',
    '--jq-mc-button-border': '#e0e0e0e0',
    '--jq-mc-button-inset-shadow': '#555555',
    '--jq-many-choice-bg': '#4ea2d9',         # Azul claro para preguntas de selección múltiple
    '--jq-numeric-bg': '#4ea2d9',             # Azul claro para preguntas numéricas
    '--jq-numeric-input-bg': '#cfeaf6',       # Azul muy suave como fondo del input
    '--jq-numeric-input-label': '#1e3a5f',    # Azul oscuro para el texto del input
    '--jq-numeric-input-shadow': '#7ab8e6',   # Azul medio para el sombreado del input
    '--jq-incorrect-color': '#f28b82',        # Rojo claro pastel para respuestas incorrectas
    '--jq-correct-color': '#8fd9a8',          # Verde claro armonizado para respuestas correctas
    '--jq-text-color': '#ffffff'              # Blanco para contraste sobre fondo azul
}


display_quiz("questions.json", colors=color_dict
            )
